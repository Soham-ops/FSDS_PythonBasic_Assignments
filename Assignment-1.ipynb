# %% [markdown]
# ## 1. What are the differences between operators and values in the following?
#
# ### *, 'hello', -87.8, -, / , +, 6

# %% [markdown]
# # Soln

# %% [markdown]
# ## operators like (*,-,/,+) are applicable on operands/values (6,-87.8,'hello')

# %%
# examples
a = 6-(-87.8)
print(a)
a = 6+(-87.8)
print(a)
a = -87.8*6
print(a)
a= -87.8/6
print(a)
a = 'hello'*6
print(a)
# Out:
# 93.8
# -81.8
# -526.8
# -14.633333333333333
# hellohellohellohellohellohello

# %% [markdown]
# ## 2. What is the difference between string and variable? spam, 'spam'

# %% [markdown]
# # Soln

# %%
#spam is a name of a variable that holds data
spam = 123
print(spam)
#'spam' is normal string aka arrangement of characters that is stored in a variable named s
s = 'spam'
print(s)
# Out:
# 123
# spam

# %% [markdown]
# ## 3. Describe three different data forms.

# %% [markdown]
# # Soln

# %%
#numeric data
a = 1
print(a)
a=1.2122
print(a)
a= 3+4j
print(a)
# Out:
# 1
# 1.2122
# (3+4j)

# %%
#strings
a = 'apple'
print(a)
a='b'
print(a)
# Out:
# apple
# b

# %%
#boolean
a = True
print(a)
a = False
print(a)
# Out:
# True
# False

# %% [markdown]
# ## 4. What makes up an expression? What are the functions of all expressions?

# %% [markdown]
# # Soln a

# %%
# Example
a = 1
b = 2
c = 3
d = a*b+c
print(f"d represents an expression made up of operators and operands")
# Out:
# d represents an expression made up of operators and operands

# %% [markdown]
# # Soln b (Function of expression)

# %%
name = input('Enter Name--')
age = int(input('Enter Age--'))
citizen = input('Is Indian (Y/N) -- ')

if age >=18 and (citizen == 'Y' or citizen =='y'): #expressions being combined using logical operators
    print('Eligble Voter')
else:
    print('Not eligible')
# Out:
# Enter Name--adsa
# Enter Age--12
# Is Indian (Y/N) -- y
# Not eligible

# %% [markdown]
# #### Like in soln b,we use expressions to write complex conditions that deal with real life scenarios

# %% [markdown]
# ## 5. In this chapter, assignment statements such as spam = 10 were added. What's the difference between a declaration and an expression?

# %% [markdown]
# # Soln

# %%
j = x*y+z # we cannot use variable before declaring them
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6da44e3a9bc3> in <module>()
# ----> 1 j = x*y+z
#
# NameError: name 'x' is not defined

# %%
x = 1
y = 2
z = 3
j = x*y+z # variable have been declared so that they can be used in expression
          # This expression may be used in some condition
print(j)
# Out:
# 5

# %% [markdown]
# ## 6. After running the following code, what does the variable bacon contain?
# ## bacon = 22
# ## bacon + 1

# %% [markdown]
# # Soln

# %%
# 22 as the incremented value has not be stored

# %% [markdown]
# ## 7. What should the values of the following two terms be?
#
# # 'spam' + 'spamspam'
# # 'spam' * 3

# %% [markdown]
# # Soln

# %%
# spamspamspam
# spamspamspam

# %% [markdown]
# ## 8. Why is it that eggs is a true variable name but 100 is not?

# %% [markdown]
# # Soln

# %%
# naming coventions come into play while we give a name to a varible
# eg

1b=5#not valid
print(1b)
b=5#valid
print(b)
# Out:
#   File "<ipython-input-20-761a82eb9c05>", line 4
#     1b=5#not valid
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [markdown]
# # Soln

# %%
a=55
ia=int(a)
fa=float(a)
sa=str(a)
print(ia,type(ia))
print(fa,type(fa))
print(sa,type(sa))
# Out:
# 55 <class 'int'>
# 55.0 <class 'float'>
# 55 <class 'str'>

# %% [markdown]
# ## 10. What is the error caused by this expression? What would you do about it?

# %%
#'I have eaten ' + 99 + ' burritos.'

# %% [markdown]
# # Soln

# %%
'I have eaten ' + 99 + ' burritos.' # Typeerror because of doing str + int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-d24137131a5c> in <module>()
# ----> 1 'I have eaten ' + 99 + ' burritos.'
#
# TypeError: must be str, not int

# %%
'I have eaten ' + '99' + ' burritos.'# resolution
# Out:
# 'I have eaten 99 burritos.'
