# %% [markdown]
# ## 1. What is the difference between shutil.copy() and shutil.copytree()?

# %% [markdown]
# # Soln

# %%
import os
import shutil

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Assignment-1.ipynb',
#  'Assignment-10.ipynb',
#  'Assignment-2.ipynb',
#  'Assignment-3.ipynb',
#  'Assignment-4.ipynb',
#  'Assignment-5.ipynb',
#  'Assignment-6.ipynb',
#  'Assignment-9.ipynb',
#  'Rough.ipynb']

# %%
f = open('work.txt','w')
f.write('Hello \n')
ls = ['This is Ram \n','This is Vishnu \n','This is Murli \n']
f.writelines(ls)
f.close()

# %%
source = 'work.txt'

# %%
os.mkdir('shutilc')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Assignment-1.ipynb',
#  'Assignment-10.ipynb',
#  'Assignment-2.ipynb',
#  'Assignment-3.ipynb',
#  'Assignment-4.ipynb',
#  'Assignment-5.ipynb',
#  'Assignment-6.ipynb',
#  'Assignment-9.ipynb',
#  'Rough.ipynb',
#  'shutilc',
#  'work.txt']

# %%
os.path.join(os.getcwd(),'shutilc')
# Out:
# 'E:\\iNeuron\\Full Stack DS\\Python Assignments(Theoritical) Answer\\shutilc'

# %%
destination = os.path.join(os.getcwd(),'shutilc')

# %%
os.listdir(destination)#pre copy
# Out:
# []

# %%
shutil.copy(source,destination)
# Out:
# 'E:\\iNeuron\\Full Stack DS\\Python Assignments(Theoritical) Answer\\shutilc\\work.txt'

# %%
os.listdir(destination)#post copy
# Out:
# ['work.txt']

# %% [markdown]
# # Copytree

# %%
os.path.join(os.getcwd(),'shutilc')
# Out:
# 'E:\\iNeuron\\Full Stack DS\\Python Assignments(Theoritical) Answer\\shutilc'

# %%
source = os.path.join(os.getcwd(),'shutilc')

# %%
nest1 = os.path.join(source,'test1')
nest1
# Out:
# 'E:\\iNeuron\\Full Stack DS\\Python Assignments(Theoritical) Answer\\shutilc\\test1'

# %%
os.mkdir(nest1)

# %%
os.listdir(source)
# Out:
# ['test1', 'work.txt']

# %%
nest2 = os.path.join(nest1,'test2')
nest2
# Out:
# 'E:\\iNeuron\\Full Stack DS\\Python Assignments(Theoritical) Answer\\shutilc\\test1\\test2'

# %%
os.mkdir(nest2)

# %%
os.listdir(nest1)
# Out:
# ['test2']

# %%
src = 'E:\\iNeuron\\Full Stack DS\\Python Assignments(Theoritical) Answer\\shutilc\\work.txt'
dest = nest2

# %%
os.listdir(nest2)#pre move
# Out:
# []

# %%
shutil.move(src,dest)
# Out:
# 'E:\\iNeuron\\Full Stack DS\\Python Assignments(Theoritical) Answer\\shutilc\\test1\\test2\\work.txt'

# %%
os.listdir(nest2)#post move
# Out:
# ['work.txt']

# %%
dst = 'E:\\iNeuron\\Full Stack DS\\Python Assignments(Theoritical) Answer\\shutilcDest'

# %%
os.listdir()#pre copytree operation
# Out:
# ['.ipynb_checkpoints',
#  'Assignment-1.ipynb',
#  'Assignment-10.ipynb',
#  'Assignment-2.ipynb',
#  'Assignment-3.ipynb',
#  'Assignment-4.ipynb',
#  'Assignment-5.ipynb',
#  'Assignment-6.ipynb',
#  'Assignment-9.ipynb',
#  'Rough.ipynb',
#  'shutilc',
#  'work.txt']

# %%
shutil.copytree(source,dst)#copy dir. struct with shutilc as source
# Out:
# 'E:\\iNeuron\\Full Stack DS\\Python Assignments(Theoritical) Answer\\shutilcDest'

# %%
os.listdir()#post copytree operation
# Out:
# ['.ipynb_checkpoints',
#  'Assignment-1.ipynb',
#  'Assignment-10.ipynb',
#  'Assignment-2.ipynb',
#  'Assignment-3.ipynb',
#  'Assignment-4.ipynb',
#  'Assignment-5.ipynb',
#  'Assignment-6.ipynb',
#  'Assignment-9.ipynb',
#  'Rough.ipynb',
#  'shutilc',
#  'shutilcDest',
#  'work.txt']

# %%
os.listdir('./shutilcDest')
# Out:
# ['test1']

# %%
os.listdir('./shutilcDest/test1')
# Out:
# ['test2']

# %%
os.listdir('./shutilcDest/test1/test2')
# Out:
# ['work.txt']

# %% [markdown]
# ### So as seen copy() will copy contents of a files whereas copytree() will replicate the entire tree structure with root = source variable

# %% [markdown]
# ## 2. What function is used to rename files?

# %% [markdown]
# # Soln

# %% [markdown]
# <li>os.rename()</li>

# %% [markdown]
# ## 3. What is the difference between the delete functions in the send2trash and shutil modules?

# %% [markdown]
# # Soln

# %% [markdown]
# <li>delete function of shutil module is used to delete the file permanently</li>
# <li>whereas the one in send2trash does not delete the file permanently ans instead sends it to the recycle bin</li>

# %% [markdown]
# ## 4. ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is equivalent to File objects’ open() method?

# %% [markdown]
# # Soln

# %% [markdown]
# <li>Quoting from the python documentation</li>
# <p>class zipfile.ZipFile(file, mode='r', compression=ZIP_STORED, allowZip64=True, compresslevel=None, *, strict_timestamps=True)</p>
# <ul>
# <li>Open a ZIP file, where file can be a path to a file (a string), a file-like object or a path-like object.</li>
# </ul>
# <li>Hence ZipFile() is the equivalent method</li>

# %% [markdown]
# ## 5. Write a program that walks through a folder tree and searches for files with a certain file extension (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder.

# %% [markdown]
# # Soln

# %%
import os
import shutil

class soln:
    
    def __init__(self):
        
        abspath = input("Please enter the 'ABSOLUTE' file path of the root that provides a nested structure else leave blank -  ")
        
        #If abspathf field is blank
        if not abspath:
            print('The field was left blank, hence creating dummy nested structure')
            self.createNested()
        
        else:
            print('Path Received')
            self.target = abspath
    
    def createNested(self):
        #Code to generate Dummy nested structure to test the code
        try:
            #Start Point
            home = os.getcwd()
            
            os.mkdir('OS Walk demo folder')
            root = os.path.join(os.getcwd(),'OS Walk demo folder')
        
            #Setting dummy target for nested search to start
            self.target = root 
            
            os.chdir(root)
            
            os.mkdir('nest1')
            f = open('test1.txt','w')
            f.close()
            f = open('test2.txt','w')
            f.close()
            root1 = os.path.join(os.getcwd(),'nest1')
            os.chdir(root1)
            
            
            os.mkdir('nest2')
            f = open('test3.txt','w')
            f.close()
            root2 = os.path.join(os.getcwd(),'nest2')
            os.chdir(root2)
            
            os.mkdir('nest3')
            root3 = os.path.join(os.getcwd(),'nest3')
            os.chdir(root3)
            
            f = open('test4.txt','w')
            f.close()
            f = open('test5.txt','w')
            f.close()
            
            #Return to Start Point
            os.chdir(home)
            
            
        except Exception as e:
            return f'Something went wrong as {e}'
        
    def searchFile(self):
        
        try:
            fileX2Search = input("Input file extenstion in this format 'txt,pdf' etc. to search accordingly - ")

            # List to store the file paths whose extension matches
            self.filePath = []

            #Traverse folder tree and find files having requiste extensions
            for i in os.walk(self.target):
                
                folder = i[0]
                fileList = i[2]
                
                for file in fileList:

                    fileX = file.split('.')[1]
                    
                    #If extension of file matches the extesnion we are searching
                    if fileX2Search == fileX:
                        
                        #note down the paths of files in self.filePath
                        path = os.path.join(folder,file)

                        self.filePath.append(path)
        
        
        except Exception as e:
            return f"Something went wrong as {e}"
        
    
    def copyFile(self):
        
        # if no file found of the requisite file path
        if not self.filePath:
            
            return 'No files found with the requisite extension'
        
        else:
        
            try:

                #Create folder where copied files are to be sent
                destFolder = input('Enter name of folder where files have to be sent')
                os.mkdir(destFolder)
                print(f"Created Folder {destFolder}")

                dest = os.path.join(os.getcwd(),destFolder)

                # Copy all files to the given folder
                for file in self.filePath:

                    print(f"MOVING {file}-------->{dest}")
                    shutil.copy(file,dest)
                    print('copied')

            except Exception as e:
                return f"Something went wrong as {e}"

# %%
obj = soln()
# Out:
# Please enter the 'ABSOLUTE' file path of the root that provides a nested structure else leave blank -
# The field was left blank, hence creating dummy nested structure

# %%
obj.searchFile()
# Out:
# Input file extenstion in this format 'txt,pdf' etc. to search accordingly - txt

# %%
obj.filePath
# Out:
# ['E:\\iNeuron\\Full Stack DS\\Python Assignments(Theoritical) Answer\\OS Walk demo folder\\test1.txt',
#  'E:\\iNeuron\\Full Stack DS\\Python Assignments(Theoritical) Answer\\OS Walk demo folder\\test2.txt',
#  'E:\\iNeuron\\Full Stack DS\\Python Assignments(Theoritical) Answer\\OS Walk demo folder\\nest1\\test3.txt',
#  'E:\\iNeuron\\Full Stack DS\\Python Assignments(Theoritical) Answer\\OS Walk demo folder\\nest1\\nest2\\nest3\\test4.txt',
#  'E:\\iNeuron\\Full Stack DS\\Python Assignments(Theoritical) Answer\\OS Walk demo folder\\nest1\\nest2\\nest3\\test5.txt']

# %%
obj.copyFile()
# Out:
# Enter name of folder where files have to be sentdemo_dest
# Created Folder demo_dest
# MOVING E:\iNeuron\Full Stack DS\Python Assignments(Theoritical) Answer\OS Walk demo folder\test1.txt-------->E:\iNeuron\Full Stack DS\Python Assignments(Theoritical) Answer\demo_dest
# copied
# MOVING E:\iNeuron\Full Stack DS\Python Assignments(Theoritical) Answer\OS Walk demo folder\test2.txt-------->E:\iNeuron\Full Stack DS\Python Assignments(Theoritical) Answer\demo_dest
# copied
# MOVING E:\iNeuron\Full Stack DS\Python Assignments(Theoritical) Answer\OS Walk demo folder\nest1\test3.txt-------->E:\iNeuron\Full Stack DS\Python Assignments(Theoritical) Answer\demo_dest
# copied
# MOVING E:\iNeuron\Full Stack DS\Python Assignments(Theoritical) Answer\OS Walk demo folder\nest1\nest2\nest3\test4.txt-------->E:\iNeuron\Full Stack DS\Python Assignments(Theoritical) Answer\demo_dest
# copied
# MOVING E:\iNeuron\Full Stack DS\Python Assignments(Theoritical) Answer\OS Walk demo folder\nest1\nest2\nest3\test5.txt-------->E:\iNeuron\Full Stack DS\Python Assignments(Theoritical) Answer\demo_dest
# copied
